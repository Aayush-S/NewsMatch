# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
keyword_extraction = "/content/gdrive/MyDrive/CSE 6242 Project/Keyword Extraction"

# %%
path = keyword_extraction

# %%
# !pip install datasets
# Out:
# Collecting datasets
#   Downloading datasets-2.18.0-py3-none-any.whl (510 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 kB 3.9 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.13.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.25.2)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets) (0.6)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 14.3 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.0.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.2)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 23.3 MB/s eta 0:00:00
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 17.6 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2024.2.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.3)
# Requirement already satisfied: huggingface-hub>=0.19.4 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.20.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.4->datasets) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2024.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Installing collected packages: xxhash, dill, multiprocess, datasets
# Successfully installed datasets-2.18.0 dill-0.3.8 multiprocess-0.70.16 xxhash-3.4.1

# %%
from datasets import load_dataset

# %%
dataset = load_dataset("hyperpartisan_news_detection", "bypublisher")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Downloading data:   0%|          | 0.00/285M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/284M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/286M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/286M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/287M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/165M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/284M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/260M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/600000 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/150000 [00:00<?, ? examples/s]

# %%
print(dataset)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'title', 'hyperpartisan', 'url', 'published_at', 'bias'],
#         num_rows: 600000
#     })
#     validation: Dataset({
#         features: ['text', 'title', 'hyperpartisan', 'url', 'published_at', 'bias'],
#         num_rows: 150000
#     })
# })

# %%
import torch
import torch.nn as nn
import transformers
from datasets import load_dataset
from tqdm import tqdm

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
#Data Preprocessing
print("\n👉 First item 'dataset[0]':")
print(dataset['train'][0])
print(len(dataset['train']))

error_values = ['null', 'n/a', 'nan', 'none', '']

# Filter out rows with errors
def clean_dataset(example):
    for column in example.keys():
        if isinstance(example["text"], str) and example["text"].lower() in error_values:
            return False
        if pd.isnull(example["bias"]):
            return False
        if pd.isnull(example["title"]):
            return False
    return True

cleaned_dataset = dataset.filter(clean_dataset)

# Output the cleaned dataset
print("Cleaned dataset size:", len(cleaned_dataset['train']))
# Out:
# 👉 First item 'dataset[0]':
# {'text': '<p>When explaining her decision to reevaluate Title IX guidelines as they pertain to sexual assault on college campuses, Secretary of Education Betsy DeVos <a href="https://www.nbcnews.com/news/us-news/betsy-devos-overhaul-obama-era-guidance-campus-sex-assault-n799471" type="external">said</a>: &#8220;Every survivor of sexual misconduct must be taken seriously. Every student accused of sexual misconduct must know that guilt is not predetermined.&#8221;</p> \n\n<p>The Obama administration&#8217;s changes to Title IX have been <a href="" type="internal">criticized</a> for, among other things, substantially lowering the burden of proof as it pertains to sexual assault, as well as denying elements of due process to the accused.</p> \n\n<p>However, many progressives are lashing out at DeVos because they hate her, and also rape culture and stuff.</p> \n\n<p>Perhaps the most grotesque attack came when Rob Ranco, a Texas attorney, tweeted Friday that &#8220;I\'m not wishing for it &#8230; but I\'d be ok if #BetsyDevos was sexually assaulted. #Sexual Assault #TitleIX.&#8221;</p> \n\n<p><a href="http://www.washingtontimes.com/news/2017/sep/9/rob-ranco-texas-lawyer-says-he-would-be-ok-if-bets/" type="external">The Washington Times</a> reports that in several other tweets (condensed for this publication), Ranco wrote: &#8220;Perhaps Betsy doesn&#8217;t understand how horrible rape is. She&#8217;s made the world more dangerous for my daughters. I need her to understand,&#8221; and &#8220;Make the world more dangerous for my daughters &#8212; intentionally &#8212; and your well being is not my concern. Full stop.&#8221;</p> \n\n<p>Ranco\'s additional tweets don\'t make his first one any less vile.</p> \n\n<p>In the wake of the overwhelming negative response, Ranco locked his Twitter profile, then <a href="https://www.redstate.com/brandon_morse/2017/09/09/cowardly-austin-lawyer-wished-sexual-assault-betsy-devos-locked-twitter-account/" type="external">deleted</a> it.</p> \n\n<p>Many on social media are calling for the attorney to be fired from The Carlson Law Firm, where he is a partner, or even disbarred:</p> \n\n<p><a href="https://twitter.com/PrisonPlanet" type="external">@PrisonPlanet</a> I\'m wishing for it... but I\'d be ok if <a href="https://twitter.com/hashtag/RobRanco?src=hash" type="external">#RobRanco</a> was disbarred.</p> \n\n<p>As of this publication, the law firm&#8217;s Twitter account has also been locked, though Ranco is still listed on the official website&#8217;s &#8220; <a href="https://www.carlsonattorneys.com/team-member/robert-ranco/" type="external">Team</a>&#8221; section.</p> \n\n<p>A <a href="https://www.change.org/p/texas-bar-association-removal-of-law-license-for-misogynistic-tweet-of-approval-of-sexual-assault-on-woman?recruiter=778517695&amp;amp;utm_source=share_petition&amp;amp;utm_medium=twitter&amp;amp;utm_campaign=share_twitter_responsive" type="external">petition</a>, which currently boasts nearly 2,200 signatures, has also been started in an effort to get the attorney disbarred.</p>', 'title': "After DeVos Announced Plans To Reexamine Title IX, Texas Attorney Tweets He Would 'Be Ok If [She] Was Sexually Assaulted'", 'hyperpartisan': True, 'url': 'https://dailywire.com/news/20858/after-devos-announced-plans-reexamine-title-ix-frank-camp', 'published_at': '2017-09-10', 'bias': 0}
# 600000
# Filter:   0%|          | 0/600000 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/150000 [00:00<?, ? examples/s]
# Cleaned dataset size: 599884

# %%
#cleaned dataset
# gensim ---> preprocessing, spacy ---> tokenization

# !pip install gensim spacy pyate
# !python -m spacy download en_core_web_sm
# Out:
# Requirement already satisfied: gensim in /usr/local/lib/python3.10/dist-packages (4.3.2)
# Requirement already satisfied: spacy in /usr/local/lib/python3.10/dist-packages (3.7.4)
# Collecting pyate
#   Downloading pyate-0.5.5.tar.gz (22 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from gensim) (1.25.2)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from gensim) (1.11.4)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim) (6.4.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.9.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (4.66.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.6.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.1.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (24.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.3.0)
# Requirement already satisfied: pandas>=1.0.3 in /usr/local/lib/python3.10/dist-packages (from pyate) (2.0.3)
# Collecting pyahocorasick>=1.4.0 (from pyate)
#   Downloading pyahocorasick-2.1.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.7/110.7 kB 1.7 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.3->pyate) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.3->pyate) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.3->pyate) (2024.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.16.3)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.4.0,>=0.1.0->spacy) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy) (2.1.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0.3->pyate) (1.16.0)
# Building wheels for collected packages: pyate
#   Building wheel for pyate (setup.py) ... done
#   Created wheel for pyate: filename=pyate-0.5.5-py3-none-any.whl size=18268 sha256=d8d0a077710890af2ca338018e2570d64659fa62392e44a8e6b9fecb90eb3681
#   Stored in directory: /root/.cache/pip/wheels/c7/03/03/02f61c63a425a29ab036a5f56cd0d7548484354963f4aabd01
# Successfully built pyate
# Installing collected packages: pyahocorasick, pyate
# Successfully installed pyahocorasick-2.1.0 pyate-0.5.5
# Collecting en-core-web-sm==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 31.9 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in /usr/local/lib/python3.10/dist-packages (from en-core-web-sm==3.7.1) (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.66.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.6.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (24.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.25.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.16.3)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.1.5)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
print(cleaned_dataset)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'title', 'hyperpartisan', 'url', 'published_at', 'bias'],
#         num_rows: 599884
#     })
#     validation: Dataset({
#         features: ['text', 'title', 'hyperpartisan', 'url', 'published_at', 'bias'],
#         num_rows: 149235
#     })
# })

# %%
import spacy
from pyate import combo_basic
from collections import Counter

# %%
# Load the English tokenizer, tagger, parser, NER, and word vectors
nlp = spacy.load("en_core_web_sm")

# %%
def preprocess_text(text): # Preprocesses text by removing stopwords and punctuation.
    doc = nlp(text)
    clean_text = ' '.join(token.lemma_ for token in doc if not token.is_stop and not token.is_punct)
    return clean_text

# %%
print(cleaned_dataset)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'title', 'hyperpartisan', 'url', 'published_at', 'bias'],
#         num_rows: 599884
#     })
#     validation: Dataset({
#         features: ['text', 'title', 'hyperpartisan', 'url', 'published_at', 'bias'],
#         num_rows: 149235
#     })
# })

# %%
'text' in cleaned_dataset['train'].column_names
# Out:
# True

# %%
# cleaned_dataset['preprocessed_text'] = [preprocess_text(text) for text in cleaned_dataset['train']['text']]

# clean the text for every entry in the dataset

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
# !pip install nltk
nltk.download('punkt')
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2023.12.25)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.2)
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
import re
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import networkx as nx
from collections import Counter
from datasets import load_dataset
import html
import time



start_time = time.time()

def remove_html_tags(text):

    # Unescape HTML entities first
    # clean = html.unescape(text)

    # Compile the regular expression for HTML tags
    # tag_re = re.compile('<.*?>')

    # tag_re = tag_re.sub(r'<[^<>]*>', '').apply(html.unescape)

    # tag_re = re.compile('<.*?>')
    # tag_re = tag_re.sub(r'<[^<>]*>', '').replace(text, '')
    # text = html.unescape(text)

    # # Use sub() to replace the HTML tags with an empty string
    # return tag_re.sub('', text).replace('<[^<>]*>', text)

    clean_text = re.sub(r'<[^>]*>', '', text)
    return clean_text

def preprocess_text(text):
    # Remove HTML tags
    text = remove_html_tags(text)

    # Remove punctuation and special characters, and convert to lowercase
    text = re.sub(r'[^\w\s]', '', text).lower()

    return text

def position_rank(tokens, window_size=5):
    graph = nx.Graph()
    for i, token in enumerate(tokens):
        for j in range(i + 1, min(i + window_size, len(tokens))):
            if not graph.has_edge(token, tokens[j]):
                graph.add_edge(token, tokens[j], weight=0)
            graph[token][tokens[j]]['weight'] += 1

    scores = nx.pagerank(graph)
    return scores

# Extract text from the entries
# texts = cleaned_dataset['train']['text']

texts = cleaned_dataset['train'][slice(0, 1000, None)]['text'] #extract text for 1 entry

# Preprocess each text
preprocessed_texts = [preprocess_text(text) for text in texts]

# Tokenize and remove stopwords
stop_words = set(stopwords.words('english'))
keywords_list = []
for text in preprocessed_texts:
    # Tokenize the text
    tokens = word_tokenize(text)

    # Remove stopwords
    filtered_tokens = [word for word in tokens if word not in stop_words]

    # Perform keyword extraction using PositionRank
    keywords = position_rank(filtered_tokens)

    # Sort the keywords by score
    sorted_keywords = sorted(keywords.items(), key=lambda x: x[1], reverse=True)

    num_keywords = 5 #top 5 keywords
    top_keywords = [keyword for keyword, score in sorted_keywords[:num_keywords]]

    keywords_list.append(top_keywords) # Append to keyword list

end_time = time.time()
elapsed_time = (end_time - start_time) / 1000
print("Runtime for 1 article:", elapsed_time, "seconds")

# Display the keywords for each entry
for i, keywords in enumerate(keywords_list):
    print(f"Keywords for entry {i+1}: {keywords}")
# Out:
# Runtime for 1 article: 0.012406352996826173 seconds
# Keywords for entry 1: ['sexual', 'ranco', 'also', 'assault', 'attorney']
# Keywords for entry 2: ['degree', 'martin', 'trayvon', 'university', 'science']
# Keywords for entry 3: ['greek', 'university', 'texas', 'said', 'fraternity']
# Keywords for entry 4: ['jewish', 'day', 'unity', 'acheinu', 'people']
# Keywords for entry 5: ['trump', 'carrier', 'jobs', 'indiana', 'company']
# Keywords for entry 6: ['balls', 'red', 'white', '22000', 'winning']
# Keywords for entry 7: ['medicare', 'plans', 'advantage', 'cuts', 'percent']
# Keywords for entry 8: ['slavery', 'said', 'homosexuality', '8212', 'denominations']
# Keywords for entry 9: ['school', 'says', 'garden', 'students', 'food']
# Keywords for entry 10: ['wildlife', 'removal', 'rattlesnake', 'said', 'area']
# Keywords for entry 11: ['trade', 'accord', 'also', 'would', 'agreement']
# Keywords for entry 12: ['trump', 'court', 'fisa', 'he8217s', 'trump8217s']
# Keywords for entry 13: ['maduro', 'said', 'protesters', 'opposition', '8212']
# Keywords for entry 14: ['careerbuilder', 'percent', 'paycheck', 'financial', 'survey']
# Keywords for entry 15: ['saudi', '911', 'carter', '28', 'pages']
# Keywords for entry 16: ['stamp', 'moon', 'sun', 'eclipse', 'since']
# Keywords for entry 17: ['apple', 'reitzes', 'big', 'new', 'news']
# Keywords for entry 18: ['sanders', 'candidate', 'supporters', 'clinton', 'primary']
# Keywords for entry 19: ['college', 'sex', 'students', 'get', 'want']
# Keywords for entry 20: ['labarbera', 'reisman', 'nazis', 'us', 'new']
# Keywords for entry 21: ['school', 'crossing', 'guard', 'westerly', 'x']
# Keywords for entry 22: ['stores', 'said', 'europe', 'online', 'company']
# Keywords for entry 23: ['8212', '8230', 'montoya', 'journal', 'coach']
# Keywords for entry 24: ['fox', 'news', 'matthews', 'republican', 'real']
# Keywords for entry 25: ['hiring', 'amp160', 'state', 'hire', 'new']
# Keywords for entry 26: ['said', 'lagarde', 'imf', 'trade', 'administration']
# Keywords for entry 27: ['war', 'empire', 'sound', 'american', 'america']
# Keywords for entry 28: ['march', 'lewis', 'book', 'people', 'john']
# Keywords for entry 29: ['trump', 'media', 'trump8217s', 'news', 'went']
# Keywords for entry 30: ['water', 'service', 'fe', 'santa', 'police']
# Keywords for entry 31: ['bodies', 'new', 'moulton', 'sheriff8217s', 'officials']
# Keywords for entry 32: ['cartoon', 'chimpanzee', 'stimulus', 'one', 'sharpton']
# Keywords for entry 33: ['revenue', 'billion', 'per', 'rose', 'percent']
# Keywords for entry 34: ['ivn', 'news', 'political', 'partisan', 'us']
# Keywords for entry 35: ['agreement', 'would', 'navajo', 'public', 'comment']
# Keywords for entry 36: ['saudi', '52017', 'arms', 'deal', 'arabia']
# Keywords for entry 37: ['megaball', 'winning', 'numbers', 'saturday', 'evenings']
# Keywords for entry 38: ['trump', 'us', 'tax', 'hes', 'law']
# Keywords for entry 39: ['people', 'pacific', 'food', 'water', 'least']
# Keywords for entry 40: ['care', 'patients', 'emergency', 'medicaid', 'poll']
# Keywords for entry 41: ['kay', 'war', 'weapons', 'intelligence', 'bush']
# Keywords for entry 42: ['stocks', 'opens', 'retirement', 'new', 'plan']
# Keywords for entry 43: ['rebels', 'rebel', 'libya', 'gaddafi', 'britain']
# Keywords for entry 44: ['president', 'jerusalem', 'would', 'could', 'trump']
# Keywords for entry 45: ['karen', 'says', 'aleppo', 'lebanon', 'syria']
# Keywords for entry 46: ['journalists', '8212', 'jail', 'injunction', 'court']
# Keywords for entry 47: ['steelcase', 'million', 'revenue', 'stock', 'opens']
# Keywords for entry 48: ['cd', 'song', 'amp160amp160amp160', 'artist', 'title']
# Keywords for entry 49: ['police', 'report', 'state', 'law', 'officers']
# Keywords for entry 50: ['shopify', 'it8217s', 'ecommerce', 'customers', 'that8217s']
# Keywords for entry 51: ['house', 'white', 'benghazi', 'coverup', 'emails']
# Keywords for entry 52: ['cuts', 'state', 'today8217s', 'richardson', 'budget']
# Keywords for entry 53: ['bank', 'said', 'singapore', 'financial', 'advisory']
# Keywords for entry 54: ['climate', 'levy', 'fuel', 'fossil', 'oil']
# Keywords for entry 55: ['uber', 'company', 'said', 'passengers', 'one']
# Keywords for entry 56: ['season', 'said', 'last', 'nelson', 'pairs']
# Keywords for entry 57: ['billion', 'budget', 'deficit', 'percent', 'government']
# Keywords for entry 58: ['used', 'carmax', 'sales', 'cents', 'billion']
# Keywords for entry 59: ['gulf', 'veterinary', 'avmf', 'pet', 'food']
# Keywords for entry 60: ['us', 'blair', 'lies', 'nodders', 'one']
# Keywords for entry 61: ['ad', 'cnn', 'president', 'media', 'trump']
# Keywords for entry 62: ['bondi', 'cooper', 'people', 'thats', 'marriage']
# Keywords for entry 63: ['fire', 'spread', 'campfire', 'brush', 'department']
# Keywords for entry 64: ['palo', 'revenue', 'alto', 'million', 'altos']
# Keywords for entry 65: ['rivera', 'points', 'national', 'florida', 'lead']
# Keywords for entry 66: ['said', 'industrial', 'september', 'output', 'august']
# Keywords for entry 67: ['points', 'michigan', 'nebraska', 'free', 'throws']
# Keywords for entry 68: ['help', 'spicy', 'hot', 'capsaicin', 'red']
# Keywords for entry 69: ['obama', 'kevin', 'stories', 'day', 'ready']
# Keywords for entry 70: ['war', 'young', 'students', 'men', 'selective']
# Keywords for entry 71: ['diversity', 'homosexuals', 'columns', 'barber', 'people']
# Keywords for entry 72: ['two', 'arrested', 'soviet', 'kultura', 'arzhak']
# Keywords for entry 73: ['project', 'south', 'legislators', 'carolina', 'electric']
# Keywords for entry 74: ['intel', 'growth', 'results', 'quarter', 'center']
# Keywords for entry 75: ['8212', 'pope', 'church', 'francis', 'catholic']
# Keywords for entry 76: ['plague', 'bubonic', 'madagascar', 'people', 'health']
# Keywords for entry 77: ['china', 'dollar', 'market', 'yuan', 'central']
# Keywords for entry 78: ['animals', '8211', 'animal', 'goat', 'slaughter']
# Keywords for entry 79: ['8212', 'aps', 'coach', 'new', 'weir']
# Keywords for entry 80: ['wedding', 'mesi', 'marry', 'happy', 'i8217m']
# Keywords for entry 81: ['cumbie', 'baptist', 'virginia', 'mount', 'vernon']
# Keywords for entry 82: ['romea', 'belen', 'archdiocese', 'said', 'investigation']
# Keywords for entry 83: ['president', 'insurance', 'law', 'said', 'even']
# Keywords for entry 84: ['publishers', 'facebook', 'revenue', 'news', 'articles']
# Keywords for entry 85: ['moore', 'campaign', 'cameraman', 'moores', 'alabama']
# Keywords for entry 86: ['abc', 'hillary', 'would', 'clinton', 'stephanopoulos']
# Keywords for entry 87: ['americans', 'game', 'canada', 'tkachuk', 'said']
# Keywords for entry 88: ['play', 'year', 'high', 'moment', 'college']
# Keywords for entry 89: ['budget', 'care', 'repeal', 'health', 'voted']
# Keywords for entry 90: ['lugar', 'republican', 'obama', 'senate', 'policy']
# Keywords for entry 91: ['mullen', 'market', 'street', 'priorities', 'usa']
# Keywords for entry 92: ['bank', 'swiss', 'hsbc', 'said', 'private']
# Keywords for entry 93: ['week', '8212', '8220the', 'show', 'million']
# Keywords for entry 94: ['stores', 'walmart', 'employees', 'wages', '2015']
# Keywords for entry 95: ['iraq', 'us', 'said', 'gen', 'david']
# Keywords for entry 96: ['need', 'holder', 'ferguson', 'riley', 'black']
# Keywords for entry 97: ['republican', 'moore', 'party', 'alabama', 'roy']
# Keywords for entry 98: ['said', 'private', 'restaurants', 'government', 'could']
# Keywords for entry 99: ['kreidich', 'would', 'lgbt', 'what8217s', 'march']
# Keywords for entry 100: ['ampgt', 'news', 'website', 'wp', '2005']
# Keywords for entry 101: ['said', 'republicans', 'mr', 'republican', 'senate']
# Keywords for entry 102: ['oil', 'market', 'crude', 'price', 'production']
# Keywords for entry 103: ['growth', 'stocks', 'opens', 'dividend', 'new']
# Keywords for entry 104: ['police', 'abraham', 'said', 'way', 'boyfriend']
# Keywords for entry 105: ['washington', 'amazon', 'post', 'story', 'disclosure']
# Keywords for entry 106: ['us', 'iraq', 'iraqi', 'government', 'troops']
# Keywords for entry 107: ['president', 'obama', 'new', 'national', 'congress']
# Keywords for entry 108: ['musk', 'hyperloop', 'people', '8211', 'would']
# Keywords for entry 109: ['percent', 'deal', 'us', 'republican', 'lower']
# Keywords for entry 110: ['said', 'tensing', 'deters', 'federal', 'police']
# Keywords for entry 111: ['social', 'new', 'opens', 'customers', 'networks']
# Keywords for entry 112: ['diamond', 'said', 'schutz', 'bar', 'friday']
# Keywords for entry 113: ['charges', '8220the', 'lawsuit', 'nguyen', 'kayden']
# Keywords for entry 114: ['sm', 'energy', 'midland', 'assets', 'basin']
# Keywords for entry 115: ['said', 'students', 'student', 'black', 'qayoumi']
# Keywords for entry 116: ['francis', 'catholic', 'said', 'church', 'catholics']
# Keywords for entry 117: ['percent', 'sampampp', '500', 'fed', 'nasdaq']
# Keywords for entry 118: ['park', 'romero', 'recreation', 'indoor', 'says']
# Keywords for entry 119: ['bp', 'gulf', 'us', 'bp8217s', 'oil']
# Keywords for entry 120: ['county', 'immigration', 'ordinance', 'said', 'cook']
# Keywords for entry 121: ['mr', 'microsoft', 'elop', 'microsofts', 'company']
# Keywords for entry 122: ['percent', 'students', 'act', 'score', 'year']
# Keywords for entry 123: ['sure', 'plants', 'get', 'good', 'spray']
# Keywords for entry 124: ['tobacco', 'ad', 'ads', 'altria', 'us']
# Keywords for entry 125: ['british', 'afghanistan', 'first', 'invasion', 'regime']
# Keywords for entry 126: ['mubarak', 'years', 'jail', 'three', 'hosni']
# Keywords for entry 127: ['taylor', 'played', '8220designing', '8220the', 'four']
# Keywords for entry 128: ['trump', 'said', 'king', 'one', 'nation']
# Keywords for entry 129: ['handgun', 'blackwater8217s', 'equipment8221', 'best', 'want']
# Keywords for entry 130: ['school', 'said', 'students', 'van', 'buren']
# Keywords for entry 131: ['workers', 'work', 'alonso', 'jobs', 'plant']
# Keywords for entry 132: ['death', 'bales', 'accused', 'could', 'charges']
# Keywords for entry 133: ['one', 'formula', 'year', 'last', 'bahrain']
# Keywords for entry 134: ['yurt', 'summer', 'full', 'futon', 'access']
# Keywords for entry 135: ['ninjas', 'ninja', 'last', 'probably', 'good']
# Keywords for entry 136: ['depp', 'caribbean', 'ride', 'sparrow', 'disneyland']
# Keywords for entry 137: ['johnson', 'ashland', 'name', 'biggest', 'singles']
# Keywords for entry 138: ['interest', 'rates', 'low', 'new', 'opens']
# Keywords for entry 139: ['spending', 'defense', 'military', 'percent', 'would']
# Keywords for entry 140: ['johnson', 'military', 'defense', 'said', 'official']
# Keywords for entry 141: ['sales', 'share', 'cents', 'million', 'rose']
# Keywords for entry 142: ['money', '8212', 'billion', 'change8221', '8220climate']
# Keywords for entry 143: ['jury', 'would', 'decide', 'sent', 'guilt']
# Keywords for entry 144: ['grover', 'norquist', 'tax', 'krugman', 'trump']
# Keywords for entry 145: ['nfl', 'anthem', 'players', '8212', 'statement']
# Keywords for entry 146: ['street', 'wall', 'billion', 'money', 'bonuses']
# Keywords for entry 147: ['baptist', 'sbc', 'news', 'open', 'trustees']
# Keywords for entry 148: ['law', 'california', 'state', 'enforcement', 'bill']
# Keywords for entry 149: ['people', 'durango', 'marijuana', 'told', 'said']
# Keywords for entry 150: ['north', 'south', 'korean', 'world', 'korea']
# Keywords for entry 151: ['members', 'people', '8211', 'church', 'three']
# Keywords for entry 152: ['percent', 'hispanics', 'would', 'voters', 'hispanic']
# Keywords for entry 153: ['senate', 'trump', 'house', 'bill', 'said']
# Keywords for entry 154: ['marquez', 'clooney', 'george', 'came', 'said']
# Keywords for entry 155: ['people', 'it8217s', 'undocumented', 'announcement', 'immigrant']
# Keywords for entry 156: ['federal', 'government', 'security', 'said', 'records']
# Keywords for entry 157: ['percent', 'gun', 'women', 'permits', 'african']
# Keywords for entry 158: ['league', 'million', 'pozzo', 'watford', 'letter']
# Keywords for entry 159: ['strategy', 'general', 'nodes', 'mcchrystal', 'new']
# Keywords for entry 160: ['panhandling', 'ordinance', 'taos', 'feet', 'news']
# Keywords for entry 161: ['walker', 'cats', 'mooney', 'home', 'said']
# Keywords for entry 162: ['emails', 'wikileaks', 'said', 'election', 'assange']
# Keywords for entry 163: ['north', 'korea', 'trump', 'said', 'equipment']
# Keywords for entry 164: ['land', 'office', 'mountain', 'village', 'property']
# Keywords for entry 165: ['bill', 'trump8217s', 'wall', 'border', 'spending']
# Keywords for entry 166: ['said', 'columbia', 'war', 'peace', 'organizers']
# Keywords for entry 167: ['bin', 'pakistan', 'us', 'laden', 'city']
# Keywords for entry 168: ['court', 'supreme', 'president', 'trump', 'justices']
# Keywords for entry 169: ['pm', 'fair', 'ministry', 'roanoke', 'messengers']
# Keywords for entry 170: ['police', 'brown', 'brown8217s', '2010', 'david']
# Keywords for entry 171: ['worth', 'net', 'median', 'home', 'americans']
# Keywords for entry 172: ['8211', 'black', 'woman8217s', 'generationally', 'shows']
# Keywords for entry 173: ['workers', 'stay', 'days', 'ten', 'labor']
# Keywords for entry 174: ['commodities', 'commodity', 'month', 'worst', 'gold']
# Keywords for entry 175: ['democrats', 'gop', 'senate', 'us', 'obama']
# Keywords for entry 176: ['us', 'kids', 'gay', 'family', 'kelly']
# Keywords for entry 177: ['economy', 'stimulus', 'slowdown', 'need', 'help']
# Keywords for entry 178: ['customer', 'report', 'corzine', 'funds', 'chairman']
# Keywords for entry 179: ['solutions', 'government', 'house', 'reforms', 'labels']
# Keywords for entry 180: ['said', 'river', 'san', 'juan', 'animas']
# Keywords for entry 181: ['kerns', 'law', 'enforcement', 'laxalt', 'opioid']
# Keywords for entry 182: ['inmates', 'acp', 'cdcr', 'female', 'prison']
# Keywords for entry 183: ['legislation', 'feinstein', 'gun', 'advertisement', 'story']
# Keywords for entry 184: ['ask', 'can8217t', 'obama', 'romney', 'arizona']
# Keywords for entry 185: ['west', 'bank', 'israel', 'settlements', 'israeli']
# Keywords for entry 186: ['boone', 'meulens', 'new', 'york', 'series']
# Keywords for entry 187: ['trump', 'user', 'obama', 'accent', 'mock']
# Keywords for entry 188: ['return', 'youre', '2013', 'money', 'tax']
# Keywords for entry 189: ['military', 'globalpost', 'el', 'egyptians', 'fattah']
# Keywords for entry 190: ['lucky', 'sum', 'winning', 'numbers', 'thursday']
# Keywords for entry 191: ['eighteen', 'numbers', 'seventeen', 'monday', 'evenings']
# Keywords for entry 192: ['house', 'statement', 'said', 'scalise', 'steve']
# Keywords for entry 193: ['marriage', 'earhart', 'first', 'even', 'feminist']
# Keywords for entry 194: ['rhinerson', 'college', 'community', 'bernie', 'education']
# Keywords for entry 195: ['obamacare', 'health', 'insurance', 'market', 'tax']
# Keywords for entry 196: ['ozone', 'western', 'asia', 'us', 'pollution']
# Keywords for entry 197: ['price', 'lawsuit', 'health', 'federal', 'sanofi']
# Keywords for entry 198: ['musical', 'cher', 'elice', 'would', 'life']
# Keywords for entry 199: ['house', 'white', 'trump', 'office', 'says']
# Keywords for entry 200: ['study', 'children', 'kids', 'pickiness', 'eat']
# Keywords for entry 201: ['national', 'stamps', 'parks', 'park', 'centennial']
# Keywords for entry 202: ['trump', 'told', 'trump8217s', 'tillerson', 'bribes']
# Keywords for entry 203: ['pigs', 'homeowner', 'footage', '8212', 'garden']
# Keywords for entry 204: ['zika', 'said', 'says', 'miami', 'control']
# Keywords for entry 205: ['global', 'climate', 'warming', '8211', 'record']
# Keywords for entry 206: ['people', 'gas', 'nuiqsut', 'drilling', 'health']
# Keywords for entry 207: ['opens', 'new', 'window', 'tesla', 'week']
# Keywords for entry 208: ['feedback', 'process', '360degree', 'employees', 'opens']
# Keywords for entry 209: ['college', 'angeles', 'los', 'students', 'community']
# Keywords for entry 210: ['pacers', 'jazz', 'said', 'ball', 'got']
# Keywords for entry 211: ['court', 'supreme', 'case', 'appeals', 'expected']
# Keywords for entry 212: ['percent', 'democratic', 'democrats', 'likely', 'block']
# Keywords for entry 213: ['said', 'irs', 'lerner', 'house', 'cole']
# Keywords for entry 214: ['drinks', 'caffeine', 'energy', 'school', 'drink']
# Keywords for entry 215: ['church', 'prop', '8', 'gay', 'mormon']
# Keywords for entry 216: ['music', 'get', 'live', 'recording', 'recordings']
# Keywords for entry 217: ['water', 'foley', 'church', 'sugar', 'baptist']
# Keywords for entry 218: ['said', 'used', 'pyne', '8212', 'recorder']
# Keywords for entry 219: ['jones', 'help', 'augusta', 'still', 'said']
# Keywords for entry 220: ['8212', 'won8217t', 'notley', 'still', 'view']
# Keywords for entry 221: ['it8217s', 'well', 'congregation', 'friends', 'one']
# Keywords for entry 222: ['virgin', 'space', 'spaceport', 'galactic', 'show']
# Keywords for entry 223: ['would', 'said', 'police', 'board', 'bill']
# Keywords for entry 224: ['trash', 'boulder', 'enforcement', 'officers', 'garbage']
# Keywords for entry 225: ['says', 'home', 'mortgage', 'percent', 'house']
# Keywords for entry 226: ['spent', 'million', 'political', 'california', 'unions']
# Keywords for entry 227: ['us', 'security', 'trump', 'national', 'adviser']
# Keywords for entry 228: ['jonathan', 'father', 'mere', 'fair', 'leftists']
# Keywords for entry 229: ['work', 'medicaid', 'people', 'said', 'states']
# Keywords for entry 230: ['beck', '8212', 'solomon', 'news', 'cnn']
# Keywords for entry 231: ['said', 'death', 'would', 'bbc', 'cited']
# Keywords for entry 232: ['social', 'security', 'benefit', 'income', 'retirement']
# Keywords for entry 233: ['school', 'palmitessa', 'teacher', 'sexual', 'facing']
# Keywords for entry 234: ['yellen', 'trump', 'back', 'lot', 'says']
# Keywords for entry 235: ['8220climate', 'change8221', 'phrase', 'global', 'people']
# Keywords for entry 236: ['said', 'magomedov', 'one', 'israeli', 'gaza']
# Keywords for entry 237: ['income', 'retirement', 'youre', 'debt', 'new']
# Keywords for entry 238: ['facebook', 'video', 'said', 'publicis', 'metric']
# Keywords for entry 239: ['stylefontsize9px', 'ampampampampampampampampampampampampampampampampampampampampampampamplta', 'mce_stylefontsize9pxampampampampampampampampampampampampampampampampampampampampampampampgtampampampampampampampampampampampampampampampampampampampampampampamplta', 'hrefhttpwwwpolldaddycom', 'phrase']
# Keywords for entry 240: ['california', 'state', 'budget', 'brown', 'process']
# Keywords for entry 241: ['war', 'slavery', 'evangelical', 'civil', 'political']
# Keywords for entry 242: ['un', 'palestinian', 'statehood', 'headquarters', 'move']
# Keywords for entry 243: ['romney', 'obama', 'voters', 'strategy', 'election']
# Keywords for entry 244: ['oil', 'prices', 'production', 'gas', 'us']
# Keywords for entry 245: ['match', 'open', '63', 'first', 'stephens']
# Keywords for entry 246: ['ponds', 'fish', 'said', 'news', 'fishing']
# Keywords for entry 247: ['daesh', 'palmyra', 'city', 'syria', 'bombing']
# Keywords for entry 248: ['mayor', 'storm', 'rain', 'california', 'francisco']
# Keywords for entry 249: ['flu', 'outbreak', 'already', 'companies', 'cases']
# Keywords for entry 250: ['maldonado', 'governor', 'sure', 'malls', 'shopping']
# Keywords for entry 251: ['said', 'santa', 'day', 'died', 'fe']
# Keywords for entry 252: ['oreilly', 'thing', 'stopped', 'noble', 'thinks']
# Keywords for entry 253: ['domino8217s', 'monaghan', 'boycott', 'shows', 'perhaps']
# Keywords for entry 254: ['it8217s', 'costume', 'wall', 'user', 'like']
# Keywords for entry 255: ['torture', 'war', 'obama', 'afghanistan', 'photos']
# Keywords for entry 256: ['said', 'herrera', 'fugal', 'found', 'three']
# Keywords for entry 257: ['bonus', 'winning', 'numbers', 'wednesday', 'evenings']
# Keywords for entry 258: ['billion', 'taxpayer', 'budget', 'defense', 'parts']
# Keywords for entry 259: ['zoo', 'cincinnati', 'products', 'says', 'hippo']
# Keywords for entry 260: ['10', '737', 'boeing', 'said', 'minister']
# Keywords for entry 261: ['jack', 'opens', 'earnings', 'new', 'window']
# Keywords for entry 262: ['authorities', 'shooting', '15yearold', 'shooter', 'intent']
# Keywords for entry 263: ['north', 'missile', 'said', 'us', 'korea']
# Keywords for entry 264: ['home', 'echo', 'get', 'hub', '8211']
# Keywords for entry 265: ['singer', 'also', 'hall', 'connie', 'carol']
# Keywords for entry 266: ['fallon', 'jimmy', 'family', 'fallon8217s', 'mother']
# Keywords for entry 267: ['collinsrector', 'california', 'feldman', 'star', 'federal']
# Keywords for entry 268: ['deepstate', 'guys', 'it8217s', 'shit', 'don8217t']
# Keywords for entry 269: ['mining', 'peru', 'lake', 'juliaca', 'protesters']
# Keywords for entry 270: ['labor', 'left', 'rejuvenate', 'would', 'nordstrom']
# Keywords for entry 271: ['kim', 'north', 'jong', 'korean', 'korea8217s']
# Keywords for entry 272: ['players', 'two', 'jury', 'batey', 'assault']
# Keywords for entry 273: ['also', 'european', 'party', 'farright', 'europe']
# Keywords for entry 274: ['program', 'social', 'students', 'want', 'justice']
# Keywords for entry 275: ['winner', '8220watershed8221', 'nicole', 'discusses', 'kidman']
# Keywords for entry 276: ['thou', 'world', 'must', 'grahn', 'roger']
# Keywords for entry 277: ['prices', 'plants', 'us', 'chicken', 'futures']
# Keywords for entry 278: ['blige', 'film', 'salma', 'international', 'hayek']
# Keywords for entry 279: ['said', 'immigrants', 'wooldridge', 'people', 'vehicle']
# Keywords for entry 280: ['results', 'dramedy', 'late', 'netflix', 'cranberries']
# Keywords for entry 281: ['percent', 'us', 'crude', 'higher', 'stocks']
# Keywords for entry 282: ['chairman', 'ceo', 'hearing', 'president', 'oil']
# Keywords for entry 283: ['migrants', 'illegal', 'also', 'africa', 'could']
# Keywords for entry 284: ['version', 'violence', 'house', 'women', 'tribal']
# Keywords for entry 285: ['barr', 'nra', 'vote', 'darden', 'house']
# Keywords for entry 286: ['posada', 'carriles', 'murder', 'ought', 'terrorist']
# Keywords for entry 287: ['bekele', 'court', 'opposition', 'ethiopia8217s', 'minister']
# Keywords for entry 288: ['climate', 'global', 'objectives', 'countries', 'balance']
# Keywords for entry 289: ['journal', 'family', 'debates', 'biden', 'bristol']
# Keywords for entry 290: ['unm', 'weir', 'season', 'said', 'academic']
# Keywords for entry 291: ['galindo', 'prison', 'guilty', 'records', 'murder']
# Keywords for entry 292: ['amazon', 'outage', 'services', 'web', 'data']
# Keywords for entry 293: ['people', 'undocumented', 'immigrants', 'us', 'think']
# Keywords for entry 294: ['trump', 'answer', 'abortion', 'thought', 'abortions']
# Keywords for entry 295: ['republican', 'heller', 'hambrick', 'ads', 'said']
# Keywords for entry 296: ['violence', 'students', 'one', 'says', 'antifa']
# Keywords for entry 297: ['alphabets', 'revenue', 'quarter', 'alphabet', 'segment']
# Keywords for entry 298: ['get', 'year', 'we8217re', 'season', 'holiday']
# Keywords for entry 299: ['team', 'sexual', 'gymnastics', 'harassment', 'metoo']
# Keywords for entry 300: ['hiv', 'strategy', 'aids', 'updated', 'people']
# Keywords for entry 301: ['abortion', 'texas', 'teen', 'custody', 'stay']
# Keywords for entry 302: ['indonesia', 'telkom', 'market', 'new', 'opens']
# Keywords for entry 303: ['zacks', 'earnings', 'hotels', 'hyatt', 'percent']
# Keywords for entry 304: ['tillman8217s', 'army', 'death', 'whether', 'killed']
# Keywords for entry 305: ['8230', 'yards', 'nevada', 'new', 'mexico']
# Keywords for entry 306: ['hindu', 'muslims', 'cow', 'people', 'even']
# Keywords for entry 307: ['daughter', 'people', 'space', 'home', 'community']
# Keywords for entry 308: ['policy', 'dwi', 'daily', 'times', 'city']
# Keywords for entry 309: ['chicago', 'video', 'crime', 'police', 'officers']
# Keywords for entry 310: ['professor', 'kalonde', 'said', 'license', 'bozeman']
# Keywords for entry 311: ['news', 'ratings', 'day', 'nbc', 'first']
# Keywords for entry 312: ['know', 'it8217s', 'people', 'think', 'scheer']
# Keywords for entry 313: ['new', 'stores', 'caseys', 'company', 'management']
# Keywords for entry 314: ['said', 'city', '___', 'virginia', 'amazon']
# Keywords for entry 315: ['8212', 'iraq', 'war', 'us', 'british']
# Keywords for entry 316: ['iraqi', 'may', 'war', 'iraq', 'one']
# Keywords for entry 317: ['new', 'opens', 'window', 'f35', 'boeing']
# Keywords for entry 318: ['shoots', 'muslim', 'obama', 'terrorists', 'center']
# Keywords for entry 319: ['must', 'schwarzenegger', 'democratic', '8212', '8220the']
# Keywords for entry 320: ['couple', 'bakery', 'religious', 'melissa', 'aaron']
# Keywords for entry 321: ['said', 'us', 'alqaida', 'lo', 'porto']
# Keywords for entry 322: ['air', 'said', 'force', 'falcons', 'morgan']
# Keywords for entry 323: ['clerk', 'man', 'durham', 'black', 'department']
# Keywords for entry 324: ['redwine', 'mark', 'boy8217s', 'bellingham', 'indictment']
# Keywords for entry 325: ['sweden', '8211', 'crime', 'trump', 'swedish']
# Keywords for entry 326: ['samsung', 'memory', 'billion', 'profit', 'trillion']
# Keywords for entry 327: ['scared', 'generation', 'make', 'little', 'awful']
# Keywords for entry 328: ['services', 'health', 'free', 'new', 'women']
# Keywords for entry 329: ['casey', 'nfl', 'former', 'portrayed', 'film']
# Keywords for entry 330: ['8212', 'party', 'white', 'class', 'workingclass']
# Keywords for entry 331: ['upper', 'east', 'side', 'like', 'gossip']
# Keywords for entry 332: ['tax', 'taxes', 'french', 'google', 'billion']
# Keywords for entry 333: ['european', 'would', 'federation', 'europe', 'states']
# Keywords for entry 334: ['growth', 'percent', 'job', 'month', 'likely']
# Keywords for entry 335: ['class', '9830', '1', '2', '3']
# Keywords for entry 336: ['security', 'interim', 'tried', 'us', 'said']
# Keywords for entry 337: ['media', 'coughing', 'outlets', 'appearances', 'public']
# Keywords for entry 338: ['chipotle', 'food', 'free', 'news', 'e']
# Keywords for entry 339: ['held', 'say', 'charged', 'police', 'girl']
# Keywords for entry 340: ['trump', 'virginia', 'robertson', 'like', 'back']
# Keywords for entry 341: ['amp160', 'relationship', 'united', 'states', 'cuba']
# Keywords for entry 342: ['baptist', 'said', 'peace', 'peacemaking', 'baptists']
# Keywords for entry 343: ['balloon', 'museum', 'tickets', '4', 'festival']
# Keywords for entry 344: ['rio', 'people', 'rancho', 'veterans', 'ceremony']
# Keywords for entry 345: ['gingrich', '8212', 'house', 'said', 'ryan']
# Keywords for entry 346: ['one', 'parents', 'students', 'speakers', 'program']
# Keywords for entry 347: ['lauper', 'march', 'speech', 'madonna', 'johansson']
# Keywords for entry 348: ['treasury', 'chief', 'secretary', 'financial', 'one']
# Keywords for entry 349: ['financial', 'job', 'companies', 'health', 'said']
# Keywords for entry 350: ['studio', 'says', 'working', 'community', 'music']
# Keywords for entry 351: ['gabor', 'miss', 'first', 'years', 'couldn8217t']
# Keywords for entry 352: ['harassment', 'training', 'says', 'sexual', 'south']
# Keywords for entry 353: ['rate', 'denmark', 'percent', 'booth', 'states']
# Keywords for entry 354: ['know', 'government', 'we8217ve', 'bachmann', 'michele']
# Keywords for entry 355: ['said', 'christie', 'lawyers', 'closures', 'lied']
# Keywords for entry 356: ['trump', 'toronto', 'hotel', 'building', 'trump8217s']
# Keywords for entry 357: ['dont', 'want', 'youre', 'print', 'tells']
# Keywords for entry 358: ['salvador', 'el', 'said', 'trans', 'rights']
# Keywords for entry 359: ['driverless', 'qualcomm', 'new', 'cars', 'opens']
# Keywords for entry 360: ['amp160', 'onestopshop', 'super', 'storeamp160', 'seems']
# Keywords for entry 361: ['novel', 'playlist', 'nelson', 'nelson8217s', 'also']
# Keywords for entry 362: ['fox', 'news', 'watters', 'women', 'program']
# Keywords for entry 363: ['food', 'fe', 'santa', 'place', 'mall']
# Keywords for entry 364: ['hives', 'year', 'percent', 'bee', 'one']
# Keywords for entry 365: ['trump', 'said', 'trump8217s', 'former', 'wednesday']
# Keywords for entry 366: ['refuge', 'also', 'sevilleta', 'amigos', 'species']
# Keywords for entry 367: ['strausskahn', 'diallo', 'york', 'new', 'said']
# Keywords for entry 368: ['casting', 'directors', 'companies', 'league', 'broadway']
# Keywords for entry 369: ['us', 'north', 'korea', 'trump', 'options']
# Keywords for entry 370: ['uranium', 'deal', 'clinton', 'one', 'cfius']
# Keywords for entry 371: ['matthews', 'thinking', 'people', 'modesty', 'left']
# Keywords for entry 372: ['games', 'spanish', 'marlins', 'team', 'season']
# Keywords for entry 373: ['laws', 'said', 'immigration', 'homan', 'ice']
# Keywords for entry 374: ['stathis', 'gender', 'children', 'youths', 'said']
# Keywords for entry 375: ['said', 'ups', 'young8217s', 'pregnant', 'court']
# Keywords for entry 376: ['israelis', 'rice', 'could', 'israel', 'issue']
# Keywords for entry 377: ['company', 'new', 'stock', 'opens', 'window']
# Keywords for entry 378: ['kraft', 'sampampp', 'foods', 'company', 'indices']
# Keywords for entry 379: ['rose', 'sales', 'shares', 'stock', 'dow']
# Keywords for entry 380: ['us', 'trump', 'war', '8212', 'syria']
# Keywords for entry 381: ['gun', 'house', 'senate', 'expected', 'amendment']
# Keywords for entry 382: ['women', 'reports', 'sexual', 'weinstein', 'also']
# Keywords for entry 383: ['zimmerman', 'show', 'gun', 'celebrity', 'piwowarski']
# Keywords for entry 384: ['new', 'islands', 'zealand', 'eastern', 'island']
# Keywords for entry 385: ['percent', 'year', 'unemployment', 'market', 'benefits']
# Keywords for entry 386: ['rose', 'suny', 'sexual', 'university', 'honorary']
# Keywords for entry 387: ['says', 'military', 'gen', 'generals', 'leaders']
# Keywords for entry 388: ['mazor', 'new', 'opens', 'taketwo', 'window']
# Keywords for entry 389: ['four', 'two', 'nineteen', 'estimated', 'mega']
# Keywords for entry 390: ['city', 'factory', 'huy', 'fong', 'odors']
# Keywords for entry 391: ['academy', 'silveria', 'percent', 'cadets', 'said']
# Keywords for entry 392: ['players', 'said', 'brain', 'cte', 'disease']
# Keywords for entry 393: ['jobs', 'zen', 'kaye', 'isaacson', 'kobun']
# Keywords for entry 394: ['church', 'thompson', 'son', 'trial', 'st']
# Keywords for entry 395: ['buffett', 'new', 'apple', 'opens', 'investors']
# Keywords for entry 396: ['band', 'miller', '8211', 'says', 'tornillo']
# Keywords for entry 397: ['read', 'romney', 'daily', 'rape', 'campaign']
# Keywords for entry 398: ['people', 'would', 'de', 'blasio', 'new']
# Keywords for entry 399: ['smith', 'year', 'winehouse', 'said', 'record']
# Keywords for entry 400: ['stringer', 'reporter', 'times', 'bragg', 'daily']
# Keywords for entry 401: ['south', 'kordofan', 'sudan', 'government', 'state']
# Keywords for entry 402: ['store', 'cook', 'said', 'jar', 'children']
# Keywords for entry 403: ['clement', 'wife', 'position', 'would', 'unm']
# Keywords for entry 404: ['debate', 'bit', 'maxed', 'whole', 'boring']
# Keywords for entry 405: ['gallons', '8212', 'crude', 'oil', 'pipeline']
# Keywords for entry 406: ['uber', 'according', 'billion', 'company', 'money']
# Keywords for entry 407: ['cases', 'pornography', 'child', 'ramachandran', '2009']
# Keywords for entry 408: ['billion', 'percent', 'net', 'share', 'per']
# Keywords for entry 409: ['said', 'drones', 'drone', 'bill', 'use']
# Keywords for entry 410: ['told', 'managers', 'warned', 'nasa', 'challenger']
# Keywords for entry 411: ['ward', 'seconddegree', 'orleans', 'new', 'murder']
# Keywords for entry 412: ['postal', 'singer', 'charles', 'atlanta', 'featuring']
# Keywords for entry 413: ['denver', 'atlanta', 'hawks', 'points', 'said']
# Keywords for entry 414: ['sales', 'gun', 'ruger', 'fifer', 'firearms']
# Keywords for entry 415: ['ireland', 'northern', 'said', 'eu', 'border']
# Keywords for entry 416: ['step', 'home', 'journey', 'single', 'war']
# Keywords for entry 417: ['data', 'complaints', 'chipotle', 'quade', 'restaurant']
# Keywords for entry 418: ['pt', 'figueroa', 'brazil', 'political', 'lula']
# Keywords for entry 419: ['apple', 'also', 'guidance', 'year', 'analysts']
# Keywords for entry 420: ['express', 'post', 'washington', 'says', 'new']
# Keywords for entry 421: ['8220the', 'young', 'pope8221', 'it8217s', 'might']
# Keywords for entry 422: ['satellite', 'parts', 'trailblazer', 'space', 'fourinch']
# Keywords for entry 423: ['north', 'korea', 'us', 'missile', 'military']
# Keywords for entry 424: ['women', 'utah', 'state', 'mormon', 'trump']
# Keywords for entry 425: ['county', 'baker', 'news', 'manager', 'newspaper']
# Keywords for entry 426: ['said', 'russia', 'kiev', 'calling', 'yanukovych']
# Keywords for entry 427: ['us', 'iraq', '2003', 'corporate', 'promotes']
# Keywords for entry 428: ['star', 'wars', 'may', 'day', 'fourth']
# Keywords for entry 429: ['drought', 'futures', 'corn', 'sales', 'plantings']
# Keywords for entry 430: ['gay', 'kelly', 'franco', 'says', 'sexuality']
# Keywords for entry 431: ['finland', 'much', 'isamp160', 'country', 'care']
# Keywords for entry 432: ['fireball', 'two', 'pick', 'seven', 'estimated']
# Keywords for entry 433: ['coal', 'bus', 'clean', 'coalition', 'year']
# Keywords for entry 434: ['million', 'year', '10', 'ceo', 'worth']
# Keywords for entry 435: ['trump', 'many', 'university', 'republican', 'women']
# Keywords for entry 436: ['discourse', 'words', 'hurt', 'feelings', 'like']
# Keywords for entry 437: ['intercontinental', '2016', 'thursday', 'source', 'cagefree']
# Keywords for entry 438: ['trump', 'governors', 'said', 'state', 'republican']
# Keywords for entry 439: ['mhealth', 'health', 'south', 'projects', 'africa']
# Keywords for entry 440: ['holocaust', 'trump', 'museum', 'trip', 'davos']
# Keywords for entry 441: ['alex', 'michael', 'morning', 'joy', 'snedecker']
# Keywords for entry 442: ['obama', 'states', 'it8217s', '2008', 'could']
# Keywords for entry 443: ['process', 'annulment', 'wants', 'says', 'get']
# Keywords for entry 444: ['mr', 'trump', 'said', 'jobs', 'already']
# Keywords for entry 445: ['recall', 'flange', 'bolts', 'hp2', 'bmw']
# Keywords for entry 446: ['immigration', 'asylum', 'deadline', 'said', 'lawyers']
# Keywords for entry 447: ['opens', 'new', 'window', 'verizon', 'ab']
# Keywords for entry 448: ['world', 'american', 'community', 'peace', 'catholic']
# Keywords for entry 449: ['authorities', 'say', 'shooting', 'charged', 'arrested']
# Keywords for entry 450: ['walmart', 'foods', 'whole', 'investors', 'growth']
# Keywords for entry 451: ['weiss', 'bathroom', 'law', 'ordinance', 'ciara']
# Keywords for entry 452: ['jenkins', 'said', 'people', 'jesus', 'old']
# Keywords for entry 453: ['labor', 'day', 'workers', 'strike', 'pullman']
# Keywords for entry 454: ['women', 'many', 'making', 'deserves', 'house']
# Keywords for entry 455: ['fire', 'said', 'didnt', 'one', 'chief']
# Keywords for entry 456: ['arms', 'eu', 'yemen', 'war', 'saudi']
# Keywords for entry 457: ['inteliquent', 'company', 'opens', 'new', 'window']
# Keywords for entry 458: ['stock', 'union', 'pacific', 'split', 'share']
# Keywords for entry 459: ['midcap', 'companies', 'also', 'opens', 'new']
# Keywords for entry 460: ['paul', 'pac', 'rand', 'crane', 'campaign']
# Keywords for entry 461: ['inequality', 'income', 'countries', 'global', 'milanovic']
# Keywords for entry 462: ['highranking', 'post', 'figures', 'washington', 'bush']
# Keywords for entry 463: ['1st', 'howitzers', 'artillery', 'battery', 'bct']
# Keywords for entry 464: ['would', 'government', 'spending', 'work', 'percent']
# Keywords for entry 465: ['descansos', '8211', 'embankment', 'san', 'antonio']
# Keywords for entry 466: ['wire', 'subscribe', '8211', '21wire', 'hour']
# Keywords for entry 467: ['korean', 'south', 'week', 'chung', 'us']
# Keywords for entry 468: ['winning', 'jc', 'numbers', 'jc10c6d9d10d', 'wednesday']
# Keywords for entry 469: ['walker', 'said', 'worm', 'fertilizer', 'really']
# Keywords for entry 470: ['police', 'officers', 'bar', 'men', 'department']
# Keywords for entry 471: ['climate', 'pruitt', 'change', 'media', 'trump']
# Keywords for entry 472: ['archbold', 'contest', 'store', 'according', 'siegel']
# Keywords for entry 473: ['netanyahu', 'said', 'media', 'political', 'netanyahu8217s']
# Keywords for entry 474: ['marcelo', 'started', 'neighbors', 'mother', 'two']
# Keywords for entry 475: ['people', 'butler', 'new', 'books', 'never']
# Keywords for entry 476: ['women', 'like', 'relationship', 'feel', 'men']
# Keywords for entry 477: ['resolution', 'world', 'baptists', 'baptist', 'work']
# Keywords for entry 478: ['olmert', 'party', 'minister', 'olmerts', 'says']
# Keywords for entry 479: ['made', 'art', 'freak', 'leandro', 'granato']
# Keywords for entry 480: ['dps', 'detective', 'man', 'detectives', 'drove']
# Keywords for entry 481: ['funds', 'active', 'managers', 'said', 'percent']
# Keywords for entry 482: ['monument', 'boulevard', 'said', 'history', 'stalin']
# Keywords for entry 483: ['falluja', 'city', 'us', 'military', 'attack']
# Keywords for entry 484: ['committee', 'said', 'collins', 'tax', 'returns']
# Keywords for entry 485: ['intelligence', 'military', 'former', 'iraqi', 'group']
# Keywords for entry 486: ['said', 'market', 'investors', 'years', 'bull']
# Keywords for entry 487: ['credit', 'september', 'billion', 'consumer', 'growth']
# Keywords for entry 488: ['record', 'steele', 'job', 'million', 'jobs']
# Keywords for entry 489: ['said', 'gutierrez', 'identify', 'still', 'body']
# Keywords for entry 490: ['story', 'people', 'messiah', 'theology', 'replacement']
# Keywords for entry 491: ['remains', 'human', 'near', 'taos', 'information']
# Keywords for entry 492: ['media', 'public', 'scare', 'say', 'people']
# Keywords for entry 493: ['pounds', 'waste', 'billion', 'trillion', 'united']
# Keywords for entry 494: ['microsoft', 'information', 'web', 'site', 'privacy']
# Keywords for entry 495: ['north', 'atmosphere', 'reentry', 'vehicle', 'missile']
# Keywords for entry 496: ['said', 'strategy', 'enemy', 'bush', 'efforts']
# Keywords for entry 497: ['ampgt', 'eampampp', 'win', 'harder', 'make']
# Keywords for entry 498: ['crash', 'alaska', 'plane', 'miles', 'site']
# Keywords for entry 499: ['fish', 'may', 'made', 'faux', 'sushi']
# Keywords for entry 500: ['yale', 'police', 'alleged', 'assaulted', 'house']
# Keywords for entry 501: ['home', 'deputies', 'one', 'investigating', 'shooting']
# Keywords for entry 502: ['8220the', 'baum', 'baum8217s', 'wizard', 'american']
# Keywords for entry 503: ['workers', 'said', 'order', 'visas', 'trump']
# Keywords for entry 504: ['us', 'crude', 'million', 'gasoline', 'inventories']
# Keywords for entry 505: ['starbucks', 'coffee', 'italian', 'italy', 'milan']
# Keywords for entry 506: ['money', 'teller', 'fbi', 'note', 'away']
# Keywords for entry 507: ['malls', 'shopping', 'said', 'centers', 'years']
# Keywords for entry 508: ['duncan', 'view', 'hunter', 'click', 'expressed']
# Keywords for entry 509: ['mwachiro', 'says', 'one', 'gay', 'book']
# Keywords for entry 510: ['daughter', 'hotel', 'kim', 'lobby', 'car']
# Keywords for entry 511: ['wharf', 'kong', 'hong', 'reics', 'said']
# Keywords for entry 512: ['new', 'won8217t', 'gun', 'loaded', 'set']
# Keywords for entry 513: ['arctic', 'ice', 'warming', 'icebergs', 'global']
# Keywords for entry 514: ['isotopes', 'season', 'said', 'relationship', 'april']
# Keywords for entry 515: ['know', 'popper', 'dorm', 'popcorn', 'would']
# Keywords for entry 516: ['space', 'pitluck', 'freerange', 'new', '8212']
# Keywords for entry 517: ['two', 'cash', 'six', 'five', 'seven']
# Keywords for entry 518: ['apa', 'torture', 'psychologists', 'military', 'governance']
# Keywords for entry 519: ['said', 'first', 'plate', 'miami', 'ball']
# Keywords for entry 520: ['film', 'dc', 'time', 'warner', 'films']
# Keywords for entry 521: ['news', 'case', 'philadelphia', 'order', 'third']
# Keywords for entry 522: ['last', 'arpaio', 'told', 'trump', 'president']
# Keywords for entry 523: ['covey', 'god', '8220i', 'sent', 'toledo']
# Keywords for entry 524: ['warfare', 'data', 'could', 'ecological', 'temperatures']
# Keywords for entry 525: ['harrington', 'would', 'war', 'movement', 'opposed']
# Keywords for entry 526: ['public', 'said', 'bill', 'access', 'fishing']
# Keywords for entry 527: ['oracle', 'google', 'us', 'judge', 'sap']
# Keywords for entry 528: ['dollar', 'major', 'basket', 'meeting', 'firm']
# Keywords for entry 529: ['trump', 'us', 'said', 'would', 'prospect']
# Keywords for entry 530: ['texas', 'percent', 'governor', 'republicans', 'national']
# Keywords for entry 531: ['germany', 'afd', 'merkel', 'election', 'party']
# Keywords for entry 532: ['residents', 'kandahar', 'security', 'city', 'field']
# Keywords for entry 533: ['percent', 'rose', 'prices', 'oil', 'stocks']
# Keywords for entry 534: ['meat', 'study', 'red', '8212', 'health']
# Keywords for entry 535: ['volatility', 'portfolio', 'short', 'investment', 'term']
# Keywords for entry 536: ['gbpusd', 'years', '31', 'sharp', 'level']
# Keywords for entry 537: ['election', 'marshall', 'app', 'says', 'day']
# Keywords for entry 538: ['lott', 'debt', 'soaries', 'baptist', 'carey8217s']
# Keywords for entry 539: ['forest', 'gishwati', 'land', 'project', 'rwandas']
# Keywords for entry 540: ['liberty', 'kabel', 'deutschland', 'vodafone', 'reuters']
# Keywords for entry 541: ['says', 'state', 'alert', 'hawaii', 'ask']
# Keywords for entry 542: ['rose', 'oil', 'percent', 'points', 'last']
# Keywords for entry 543: ['clap', 'along', 'nappy', 'cuz', 'know']
# Keywords for entry 544: ['best', 'nominated', '8220moonlight8221', 'category', 'la']
# Keywords for entry 545: ['forensic', 'department', 'evidence', 'science', 'justice']
# Keywords for entry 546: ['film', 'taos', 'jackson', 'says', 'land']
# Keywords for entry 547: ['isis', 'paris', 'attacks', 'times', 'york']
# Keywords for entry 548: ['find', 'year', 'intention', 'set', 'guide']
# Keywords for entry 549: ['lottery', 'spent', 'last', 'americans', 'governments']
# Keywords for entry 550: ['said', 'lam', 'swift', '8220i', 'new']
# Keywords for entry 551: ['us', 'crude', 'oil', 'production', 'recently']
# Keywords for entry 552: ['stelter', 'kurson', 'media', 'think', '8212']
# Keywords for entry 553: ['wheat', 'kaufman', 'price', 'people', 'real']
# Keywords for entry 554: ['program', 'psp', 'said', 'statement', 'new']
# Keywords for entry 555: ['fed', 'one', 'creation', 'hundred', '8211']
# Keywords for entry 556: ['microsoft', 'service', 'slack', 'new', 'teams']
# Keywords for entry 557: ['percent', 'oprah', 'trump', 'survey', '44']
# Keywords for entry 558: ['trump', 'us', 'jerusalem', 'officials', 'said']
# Keywords for entry 559: ['standards', 'bill', 'whole', 'school', 'schools']
# Keywords for entry 560: ['money', 'says', 'couples', 'financial', 'it8217s']
# Keywords for entry 561: ['murray', 'said', 'people', 'one', 'get']
# Keywords for entry 562: ['carlson', 'first', 'said', 'speech', 'uk']
# Keywords for entry 563: ['8220deutschland', 'german', '8217868221', 'series', 'west']
# Keywords for entry 564: ['thursday', 'tatishvili', 'black', 'vision', 'coleman']
# Keywords for entry 565: ['software', 'data', 'carrier', 'iq', 'said']
# Keywords for entry 566: ['said', 'it8217s', 'vla', 'astronomy', 'also']
# Keywords for entry 567: ['shell', 'oil', 'gas', 'natural', 'prices']
# Keywords for entry 568: ['bank', 'richardson', 'exim', 'abengoa', 'us']
# Keywords for entry 569: ['new', 'company', 'shares', 'growth', 'opens']
# Keywords for entry 570: ['workers', 'republic', 'teamsters', 'says', 'work']
# Keywords for entry 571: ['alameda', 'rail', 'project', 'edith', 'proposing']
# Keywords for entry 572: ['breasts', 'sexual', 'used', 'girls', 'discourage']
# Keywords for entry 573: ['dream', 'obama', 'immigration', 'reform', 'act']
# Keywords for entry 574: ['medicaid', 'states', 'said', 'health', 'work']
# Keywords for entry 575: ['would', 'apple', 'cisco', 'shares', 'microsoft']
# Keywords for entry 576: ['percent', 'growth', 'oil', 'manufacturing', 'months']
# Keywords for entry 577: ['united', 'states', 'international', 'weapons', 'us']
# Keywords for entry 578: ['steel', 'company', 'said', 'thyssenkrupp', 'merger']
# Keywords for entry 579: ['saic', 'said', 'government', 'percent', 'shares']
# Keywords for entry 580: ['price', 'markets', 'market', 'speculation', 'go']
# Keywords for entry 581: ['said', 'louisville', 'plaintiffs', 'reynolds', 'settlements']
# Keywords for entry 582: ['bill', 'said', 'would', 'senate', 'licenses']
# Keywords for entry 583: ['acl', 'murray', 'bear', 'trial', 'new']
# Keywords for entry 584: ['ofamp160the', 'toamp160the', 'political', 'party', 'authorities']
# Keywords for entry 585: ['immigration', 'immigrants', 'mccain', 'rubio', 'us']
# Keywords for entry 586: ['news', 'corp', 'fcc', 'congress', 'victims']
# Keywords for entry 587: ['two', 'estimated', 'jackpot', 'three', 'mega']
# Keywords for entry 588: ['kleinheinz', 'future', 'restore', 'irvin', 'april']
# Keywords for entry 589: ['tax', 'credit', 'loophole', 'child', 'kids']
# Keywords for entry 590: ['said', 'us', 'syria', 'attack', 'reuters']
# Keywords for entry 591: ['catholic', 'worker', 'movement', 'peter', 'us']
# Keywords for entry 592: ['holder', 'press', 'serious', 'wednesday', 'attorney']
# Keywords for entry 593: ['rove', 'team', 'even', 'that8217s', 'going']
# Keywords for entry 594: ['trump', 'na', 'gon', 'russians', 'democrats']
# Keywords for entry 595: ['county', '8212', 'young', 'sex', 'wiener']
# Keywords for entry 596: ['voter', 'fraud', 'said', 'evidence', 'election']
# Keywords for entry 597: ['burke', 'trout', 'las', 'hall', 'new']
# Keywords for entry 598: ['lugo8217s', 'president', 'political', 'lugo', 'impeachment']
# Keywords for entry 599: ['infrastructure', 'chao', 'said', 'projects', 'plan']
# Keywords for entry 600: ['companies', 'business', '8211', 'like', 'that8217s']
# Keywords for entry 601: ['blackberry', 'new', 'rim', '10', 'us']
# Keywords for entry 602: ['local', 'obama', 'recession', 'percent', 'government']
# Keywords for entry 603: ['tax', 'would', 'rate', 'businesses', 'pay']
# Keywords for entry 604: ['people', 'name', 'law', 'native', 'practices']
# Keywords for entry 605: ['benefit', 'social', 'security', 'benefits', 'new']
# Keywords for entry 606: ['unm', 'said', 'million', 'forte', 'state']
# Keywords for entry 607: ['news', 'new', 'katrina', 'political', 'analyst']
# Keywords for entry 608: ['tv', 'says', 'traditional', 'like', 'video']
# Keywords for entry 609: ['said', 'community', 'people', 'emanuel', 'black']
# Keywords for entry 610: ['lobbyists', 'obama', 'said', 'ban', 'boards']
# Keywords for entry 611: ['o8217reilly', 'cnn', 'comment', 'star', 'bill']
# Keywords for entry 612: ['carson', 'man', 'woman', 'rights', 'know']
# Keywords for entry 613: ['methane', 'interior', 'rule', 'federal', 'lands']
# Keywords for entry 614: ['business', 'start', 'services', 'businesses', 'training']
# Keywords for entry 615: ['photo', 'school', 'police', 'girl', 'say']
# Keywords for entry 616: ['dynasty', 'northern', 'opens', 'new', 'window']
# Keywords for entry 617: ['starbucks', 'company', 'new', 'schultz', 'refugees']
# Keywords for entry 618: ['said', 'elections', 'election', 'city', 'albuquerque']
# Keywords for entry 619: ['reporter', 'world', 'times', 'walla', 'nieman']
# Keywords for entry 620: ['methane', 'said', 'rule', 'gas', 'groups']
# Keywords for entry 621: ['press', 'white', 'treaty', 'house', 'signing']
# Keywords for entry 622: ['said', 'african', 'libya', 'burkina', 'tackle']
# Keywords for entry 623: ['lobster', 'mcdonalds', 'new', 'opens', 'roll']
# Keywords for entry 624: ['slut', 'women', 'sexual', 'like', 'want']
# Keywords for entry 625: ['man', 'canal', 'found', 'fortune', 'says']
# Keywords for entry 626: ['hanson', 'message', 'national', 'tractor', '8220he']
# Keywords for entry 627: ['vote', 'says', 'assad', 'many', 'dog']
# Keywords for entry 628: ['said', 'trump', 'court', 'pryor', 'senate']
# Keywords for entry 629: ['tax', 'estate', 'taxes', 'father', 'income']
# Keywords for entry 630: ['percent', 'jindal', 'iowa', 'poll', 'bobby']
# Keywords for entry 631: ['slavery', 'speech', 'mcqueen', 'million', 'people']
# Keywords for entry 632: ['intelligence', 'officials', 'house', 'election', 'white']
# Keywords for entry 633: ['obama', 'chiefs', 'night', 'daily', 'abdullah']
# Keywords for entry 634: ['steyer', 'pipeline', 'said', 'issue', 'francisco']
# Keywords for entry 635: ['hulu', 'shows', 'new', 'spanishlanguage', 'corp']
# Keywords for entry 636: ['fence', 'israeli', 'people', 'expert', 'one']
# Keywords for entry 637: ['solidarity', 'workers', 'leading', 'deputy', 'pts']
# Keywords for entry 638: ['peyronie8217s', 'disease', 'may', 'tramadol', '2013']
# Keywords for entry 639: ['transgender', 'said', 'military', 'medical', 'pentagon']
# Keywords for entry 640: ['flags', 'volunteers', 'day', 'said', 'memorial']
# Keywords for entry 641: ['wheels', 'vista', 'company', 'peltier', 'alan']
# ...
# Keywords for entry 788: ['bishop', 'prosecutors', 'say', 'exgirlfriend', 'charged']
# Keywords for entry 789: ['program', 'lockheed', 'f35', 'jets', 'trump']
# Keywords for entry 790: ['gay', 'people', 'spirit', 'taung', 'byone']
# Keywords for entry 791: ['right', 'two', 'first', 'employees', 'video']
# Keywords for entry 792: ['trump', 'stupak', 'said', 'new', 'game8221']
# Keywords for entry 793: ['series', 'said', 'escobar', 'drug', 'colombia']
# Keywords for entry 794: ['monsegur', 'anonymous', 'fbi', 'charlie', 'rose']
# Keywords for entry 795: ['gilead', 'revenue', 'sciences', 'stock', 'pipeline']
# Keywords for entry 796: ['deal', 'shares', '2017', '21', 'september']
# Keywords for entry 797: ['new', 'could', 'mexico', 'waivers', 'virgin']
# Keywords for entry 798: ['wall', 'democrats', 'said', 'republicans', 'shut']
# Keywords for entry 799: ['city', 'attorney', 'garza', 'connelly', 'said']
# Keywords for entry 800: ['tigers', 'verlander', 'era', 'get', 'detroit']
# Keywords for entry 801: ['site', 'journalism', 'citizen', 'article', 'people']
# Keywords for entry 802: ['said', 'new', 'us', 'china', 'gun']
# Keywords for entry 803: ['cards', 'said', 'help', 'housing', 'panhandlers']
# Keywords for entry 804: ['hannah', 'matthew', 'jesse', 'want', 'matthew8217s']
# Keywords for entry 805: ['president', 'owners', 'don8217t', 'trump', 'gon']
# Keywords for entry 806: ['packers', 'he8217s', 'said', 'play', '8212']
# Keywords for entry 807: ['cia', 'opium', 'us', 'would', 'laos']
# Keywords for entry 808: ['letter', 'president', 'iran', 'republicans', 'really']
# Keywords for entry 809: ['clinton', 'death', 'foundation', 'deaths', 'haitian']
# Keywords for entry 810: ['said', 'reuters', 'photo', 'pdvsa', 'oil']
# Keywords for entry 811: ['hotspots', 'exit', 'billion', '8212', 'miles']
# Keywords for entry 812: ['intel', 'spending', 'investments', 'company', 'intels']
# Keywords for entry 813: ['percent', 'said', 'million', 'us', 'opec']
# Keywords for entry 814: ['mirasolo', 'child', 'custody', 'years', 'kiessling']
# Keywords for entry 815: ['animals', 'book', 'time', '8212', 'moral']
# Keywords for entry 816: ['french', 'according', 'state', 'man', 'security']
# Keywords for entry 817: ['8212', 'race', 'tour', 'one', 'riders']
# Keywords for entry 818: ['first', 'american', 'good', 'nation', 'trump']
# Keywords for entry 819: ['boston', 'verdict', 'reporter', 'days', 'herald']
# Keywords for entry 820: ['prisoners', 'us', 'foia', 'war', 'afghan']
# Keywords for entry 821: ['president', 'dinner', 'show', 'says', 'house']
# Keywords for entry 822: ['white', 'bill', 'clinton', 'house', 'woman']
# Keywords for entry 823: ['said', 'prize', 'nobel', 'hart', 'holmstrom']
# Keywords for entry 824: ['europe', 'jets', 'officials', 'f35', 'us']
# Keywords for entry 825: ['mastercard', 'deals', 'year', 'services', 'investors']
# Keywords for entry 826: ['billion', 'said', 'company', 'year', 'us']
# Keywords for entry 827: ['power', 'columbus8217', 'new', 'juicy', 'nipple']
# Keywords for entry 828: ['panetta', 'clinton', 'war', 'bernie', 'supporters']
# Keywords for entry 829: ['reits', 'equity', 'income', 'investors', 'properties']
# Keywords for entry 830: ['exchange', 'health', 'enrollment', 'first', 'plan']
# Keywords for entry 831: ['8211', 'china', 'us', 'eurasia', 'silk']
# Keywords for entry 832: ['statement', 'kayani', 'court', 'pakistan', 'military']
# Keywords for entry 833: ['government', 'republicans', 'gon', 'na', 'get']
# Keywords for entry 834: ['apple', 'watch', 'stores', '8212', 'online']
# Keywords for entry 835: ['said', 'girlfriend', 'deputies', 'spokesman', 'facing']
# Keywords for entry 836: ['ethanol', 'cellulosic', 'us', 'energy', 'would']
# Keywords for entry 837: ['tata', 'mistry', 'legal', 'said', 'group']
# Keywords for entry 838: ['percent', 'us', 'shares', 'markets', 'election']
# Keywords for entry 839: ['opens', 'new', 'window', 'merrimack', 'stocks']
# Keywords for entry 840: ['naloxone', 'spray', 'narcan', 'q', 'market']
# Keywords for entry 841: ['teacher', 'student', 'boy', 'school', 'classroom']
# Keywords for entry 842: ['city', 'change', 'us', '8211', 'alzheimer8217s']
# Keywords for entry 843: ['first', 'inauguration', 'obama', 'oath', 'phrase']
# Keywords for entry 844: ['8211', 'afbranco', 'cartoons', 'eliminate', 'tragedies']
# Keywords for entry 845: ['democrats', 'trump', 'deal', 'said', 'immigration']
# Keywords for entry 846: ['said', 'people', 'ashley', 'madison', 'information']
# Keywords for entry 847: ['us', 'kia', 'said', 'year', 'mexico']
# Keywords for entry 848: ['tea', 'longjing', 'leaves', 'picking', 'season']
# Keywords for entry 849: ['people', 'seemed', 'march', 'love', 'police']
# Keywords for entry 850: ['north', 'south', 'korean', 'world', 'korea']
# Keywords for entry 851: ['8212', 'state', '101', 'receiving', 'points']
# Keywords for entry 852: ['8212', 'minister', 'prime', 'thatcher', 'policies']
# Keywords for entry 853: ['plc', 'pound', 'said', 'shares', 'wednesday']
# Keywords for entry 854: ['billion', 'company', 'year', 'said', 'rose']
# Keywords for entry 855: ['attorney', 'stores', 'nebraska', 'state', 'liquor']
# Keywords for entry 856: ['tongue', 'mr', 'nobel', 'prize', 'minorities']
# Keywords for entry 857: ['people', 'sharing', 'years', 'see', 'know']
# Keywords for entry 858: ['pratt', 'people', 'would', 'blue', 'movies']
# Keywords for entry 859: ['moore', 'fire', 'lost', 'home', 'statement']
# Keywords for entry 860: ['manual', 'us', 'counterinsurgency', 'use', 'torture']
# Keywords for entry 861: ['mission', 'local', 'needs', 'evaluate', 'villagers']
# Keywords for entry 862: ['top', 'ten', 'voters', 'fiorina', 'ranking']
# Keywords for entry 863: ['says', 'children', 'karachi', 'street', 'kids']
# Keywords for entry 864: ['business', 'greenberg', 'cuba', 'insurance', 'starr']
# Keywords for entry 865: ['said', 'engines', 'pratt', 'cost', 'f35']
# Keywords for entry 866: ['sonic', 'youth', 'album', 'years', 'back']
# Keywords for entry 867: ['rikaart', 'kevin', 'show', 'greg', 'would']
# Keywords for entry 868: ['beat', '62', 'dimitrov', 'open', 'nadal']
# Keywords for entry 869: ['inappropriate', 'female', 'researchers', 'male', 'members']
# Keywords for entry 870: ['billion', 'share', 'revenue', 'quarter', 'cents']
# Keywords for entry 871: ['i8217m', 'platform', 'tree', 'rope', 'mountain']
# Keywords for entry 872: ['ebola', 'health', 'worker', 'said', 'nebraska']
# Keywords for entry 873: ['networking', 'youre', 'network', 'new', 'help']
# Keywords for entry 874: ['said', 'procession', 'statue', 'year', 'small']
# Keywords for entry 875: ['lucky', 'sum', 'winning', 'numbers', 'thursday']
# Keywords for entry 876: ['kashkari', 'large', 'financial', 'crisis', 'speech']
# Keywords for entry 877: ['new', 'veterans', 'opens', 'window', 'companies']
# Keywords for entry 878: ['gonzalez', 'arrest', 'border', 'authorities', 'patrol']
# Keywords for entry 879: ['painting', 'elliott', 'governor', 'governors', 'next']
# Keywords for entry 880: ['us', 'cuban', 'cuba', 'delaurentis', 'obama']
# Keywords for entry 881: ['cuomo', 'everybody', 'clinton', 'pressed', 'release']
# Keywords for entry 882: ['landline', 'cell', 'respondents', 'phone', 'sample']
# Keywords for entry 883: ['bin', 'laden', 'laden8217s', 'writes', 'war']
# Keywords for entry 884: ['said', 'president', 'us', 'lula', 'would']
# Keywords for entry 885: ['madsen', 'evidence', 'hannity', 'president', 'knowledge']
# Keywords for entry 886: ['points', 'scored', 'half', 'game', 'first']
# Keywords for entry 887: ['epa', 'said', 'cars', 'testing', 'vw']
# Keywords for entry 888: ['police', 'mcafee', 'reward', 'indianapolis', 'indiana']
# Keywords for entry 889: ['city', '8212', 'pnm', 'percent', 'power']
# Keywords for entry 890: ['microphone', 'mars', 'sound', 'sounds', 'like']
# Keywords for entry 891: ['gilead', 'sciences', 'shares', 'billion', 'market']
# Keywords for entry 892: ['companies', 'news', 'products', 'greenberg', 'journal']
# Keywords for entry 893: ['said', 'columbus', 'city', 'statue', 'council']
# Keywords for entry 894: ['thursday', 'futures', '01', 'said', 'eastern']
# Keywords for entry 895: ['percent', 'sales', 'year', 'ago', 'months']
# Keywords for entry 896: ['johnson', 'american', 'round', 'withdrew', 'last']
# Keywords for entry 897: ['pizza', 'hut', 'images', 'world', 'photo']
# Keywords for entry 898: ['beacon', 'free', 'story', 'clinton', 'agreement']
# Keywords for entry 899: ['elections', 'subcommittee', 'issues', 'said', 'house']
# Keywords for entry 900: ['alberta', 'mps', 'liberal', 'people', 'say']
# Keywords for entry 901: ['permits', 'home', 'new', 'construction', 'metro']
# Keywords for entry 902: ['italian', 'italy', 'immigrants', 'refugees', 'france']
# Keywords for entry 903: ['beckham', 'marshall', 'mcadoo', 'browns', 'game']
# Keywords for entry 904: ['new', 'site', 'window', 'opens', 'also']
# Keywords for entry 905: ['per', 'google', 'might', 'user', 'chromebooks']
# Keywords for entry 906: ['yemen', 'refugees', 'immigrants', 'illegal', 'news']
# Keywords for entry 907: ['dissent', '8212', 'silent', 'one', 'think']
# Keywords for entry 908: ['syrian', 'flag', 'said', 'hashem', 'community']
# Keywords for entry 909: ['chief', 'ambac', 'financial', 'settle', 'agreed']
# Keywords for entry 910: ['believe', 'kidnappers', 'baghdad', 'negotiations', 'christian']
# Keywords for entry 911: ['daus', 'facebook', 'investors', 'opens', 'niu']
# Keywords for entry 912: ['8211', 'state', 'school', 'political', 'term']
# Keywords for entry 913: ['energy', 'california', 'power', 'would', 'california8217s']
# Keywords for entry 914: ['africa', 'us', 'trump8217s', 'african', 'countries']
# Keywords for entry 915: ['species', 'lukhtanov', 'specimens', 'butterfly', 'new']
# Keywords for entry 916: ['inflators', 'recall', 'vehicles', 'said', 'takata']
# Keywords for entry 917: ['students', 'university', 'national', 'student', 'college']
# Keywords for entry 918: ['candidates', 'forums', 'cerrillos', '1420', 'justice']
# Keywords for entry 919: ['trump', 'merry', 'bannon', 'white', 'merely']
# Keywords for entry 920: ['three', 'hits', 'mexico', 'new', '10']
# Keywords for entry 921: ['gun', 'new', 'guncontrol', 'mayor', 'said']
# Keywords for entry 922: ['black', 'students', 'officer', 'student', 'incident']
# Keywords for entry 923: ['county', 'department', 'federal', 'justice', 'jurisdictions']
# Keywords for entry 924: ['vw', 'us', 'dealers', 'settlement', 'vehicles']
# Keywords for entry 925: ['los', 'alamos', 'roberts', 'light', 'aspartame']
# Keywords for entry 926: ['percent', 'harassment', 'sexual', 'said', 'thought']
# Keywords for entry 927: ['coke', 'arlington', 'said', '1941', 'george']
# Keywords for entry 928: ['left', 'president', 'trump', 'american', 'war']
# Keywords for entry 929: ['dean', 'iraq', 'would', 'support', 'war']
# Keywords for entry 930: ['kawczynski', 'said', 'town', 'white', 'people']
# Keywords for entry 931: ['depression', 'said', 'like', '8220i', 'dane']
# Keywords for entry 932: ['job', 'boss', 'dale', 'help', 'ask']
# Keywords for entry 933: ['independent', 'democrat', 'lieberman', 'democrats', 'caucuses']
# Keywords for entry 934: ['weapon', 'mateen', 'attack', 'rifle', 'used']
# Keywords for entry 935: ['christian', '53', '44', '49', '57']
# Keywords for entry 936: ['church', 'early', 'christians', 'would', 'christs']
# Keywords for entry 937: ['agreements', 'companies', 'water', 'effects', 'natural']
# Keywords for entry 938: ['8212', 'ceasefire', 'gaza', 'israel', 'still']
# Keywords for entry 939: ['reform', '8212', 'students', 'one', 'education']
# Keywords for entry 940: ['rovio', 'million', 'said', 'birds', 'year']
# Keywords for entry 941: ['shares', 'stocks', 'fell', 'results', 'tech']
# Keywords for entry 942: ['ian', '8211', 'challenges', 'fracking', 'wire']
# Keywords for entry 943: ['relevant', 'securities', 'disclosure', 'class', 'none']
# Keywords for entry 944: ['best', 'society', 'york', 'new', 'bird8221']
# Keywords for entry 945: ['gallup', 'relations', 'race', 'found', 'blacks']
# Keywords for entry 946: ['hiv', 'cdc', '8211', 'americans', 'care']
# Keywords for entry 947: ['obama', 'romney', 'mitt', 'debate', '8220known']
# Keywords for entry 948: ['college', 'ithaca', 'students', 'faculty', 'community']
# Keywords for entry 949: ['quiz', 'tax', 'used', '1', 'says']
# Keywords for entry 950: ['million', 'campaign', 'spent', 'clinton8217s', 'ads']
# Keywords for entry 951: ['johnston', 'church', 'said', 'embezzlement', 'sheriff8217s']
# Keywords for entry 952: ['small', 'farm', 'farms', 'cannabis', 'one']
# Keywords for entry 953: ['said', 'tesla', 'engines', 'would', 'production']
# Keywords for entry 954: ['markets', 'surged', 'index', 'points', 'central']
# Keywords for entry 955: ['organizers', 'union', 'guys', '8212', 'wage']
# Keywords for entry 956: ['house', 'districts', 'court', 'week', 'senate']
# Keywords for entry 957: ['iraq', 'invasion', 'iraq8217s', 'stolen', 'items']
# Keywords for entry 958: ['party', 'leadership', 'unions', 'york', 'new']
# Keywords for entry 959: ['engine', 'cfm', 'engines', 'percent', 'pratt']
# Keywords for entry 960: ['inflation', 'said', 'yellen', 'would', 'ms']
# Keywords for entry 961: ['stocks', 'company', 'said', 'opens', 'new']
# Keywords for entry 962: ['beef', 'plant', 'alberta', 'processing', 'werman']
# Keywords for entry 963: ['get', '8211', 'ab', 'it8217s', 'budget']
# Keywords for entry 964: ['journalist', 'guardian', 'taken', 'hooded', 'award']
# Keywords for entry 965: ['romney', 'ohio', 'rasmussen', 'election', 'one']
# Keywords for entry 966: ['social', 'welfare', 'state', 'zamora', 'foucault']
# Keywords for entry 967: ['body', 'could', 'scanners', 'security', 'explosives']
# Keywords for entry 968: ['us', 'afghan', 'said', 'washington', 'post']
# Keywords for entry 969: ['likely', 'conflict', 'syria', 'said', 'islamic']
# Keywords for entry 970: ['faith', 'people', 'islam', 'new', '8211']
# Keywords for entry 971: ['obergefell', 'trump', 'donald', 'repeal', 'enable']
# Keywords for entry 972: ['mr', 'attack', 'said', 'syrian', 'chemical']
# Keywords for entry 973: ['said', 'party', '8211', 'democratic', 'pearce']
# Keywords for entry 974: ['trump', 'virginia', 'said', 'clinton', 'state']
# Keywords for entry 975: ['months', 'said', 'deployments', 'army', 'casey']
# Keywords for entry 976: ['parts', 'business', 'amp160', 'genuine', 'enterprise']
# Keywords for entry 977: ['marriage', 'samesex', 'united', 'americans', 'kentucky']
# Keywords for entry 978: ['craft', 'beer', 'new', 'anheuserbusch', 'opens']
# Keywords for entry 979: ['georgia', 'deal', 'weather', 'people', 'state']
# Keywords for entry 980: ['oil', 'companies', 'zanganeh', 'iran8217s', 'accord']
# Keywords for entry 981: ['knife', 'simpson', 'cop', 'found', 'friend']
# Keywords for entry 982: ['times', 'quote', 'campaign', 'romney', 'romney8217s']
# Keywords for entry 983: ['university', 'event', 'said', 'police', 'speech']
# Keywords for entry 984: ['financial', 'said', 'money', 'married', 'one']
# Keywords for entry 985: ['visas', 'workers', 'h2b', 'costs', 'american']
# Keywords for entry 986: ['nfl', 'elliott', 'court', 'running', 'suspension']
# Keywords for entry 987: ['gun', 'smith', 'wesson', 'ampamp', 'new']
# Keywords for entry 988: ['food', 'san', 'mobile', 'francisco', 'trucks']
# Keywords for entry 989: ['security', 'jordanian', 'gunmen', 'islamic', 'said']
# Keywords for entry 990: ['us', 'assange', 'manning', 'wikileaks', 'government']
# Keywords for entry 991: ['first', 'obama', 'lady', 'michelle', 'communities']
# Keywords for entry 992: ['said', 'gas', 'pipeline', 'dominion', 'virginia']
# Keywords for entry 993: ['realists', 'foreign', 'would', 'views', 'realist']
# Keywords for entry 994: ['million', 'yankees', 'era', 'tax', 'season']
# Keywords for entry 995: ['must', 'vietnam', 'us', 'war', 'world']
# Keywords for entry 996: ['said', 'fishing', 'fishermen', 'nguyen', 'foreign']
# Keywords for entry 997: ['state', 'senate', 'confederate', 'flag', 'agreed']
# Keywords for entry 998: ['zionist', 'israel', 'israeli', 'palestine', 'establishment']
# Keywords for entry 999: ['innings', '8212', 'friedman8217s', 'athletes', 'high']
# Keywords for entry 1000: ['ppps', 'said', 'companies', 'private', 'health']

# %%
#write to CSV
import csv

# Define your CSV file name
output = 'keywords.csv'

cleaned_dataset['train']

# Open the CSV file for writing
with open(output, mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)

    # Write the header row
    writer.writerow(['Entry Index', 'Keywords', 'Title', 'Text', 'Bias'])

    # # Write the keywords for each entry
    # for i, keywords in enumerate(keywords_list):
    #     # Write the entry index and the keywords joined by a comma
    #     writer.writerow([f"Entry {i+1}", ', '.join(keywords)])

    #write to CSV

    for i, (entry, keywords) in enumerate(zip(cleaned_dataset['train'], keywords_list)):
        # Extract information from the entry
        index = i + 1
        keywords = ', '.join(keywords)
        title = entry['title']
        text = entry['text']
        bias = entry['bias']

        # Write the information to the CSV file
        writer.writerow([index, keywords, title, text, bias])

# %%
import os
os.getcwd()
# Out:
# '/content'

# %%
location = "/content/gdrive/MyDrive/CSE 6242 Project/Keyword Extraction"
os.path.join(location, 'keywords.csv')
# Out:
# '/content/gdrive/MyDrive/CSE 6242 Project/Keyword Extraction/keywords.csv'

# %%
os.getcwd()
# Out:
# '/content'

# %%
# keywords = extract_keywords_with_positionrank(cleaned_dataset['train']['text'])

# %%
# keywords = extract_keywords_with_positionrank(cleaned_dataset)
# for article, keys in keywords.items():
#     print("Article:", article[:30], "...", "\nKeywords:", keys, "\n")

# %%
# from transformers import AutoTokenizer

# model_checkpoint = 'bert-base-uncased'
# tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)

# def tokenize_function(examples):
#     return tokenizer(examples['text'], padding='max_length', truncation=True, max_length=128)

# tokenized_datasets = cleaned_dataset.map(tokenize_function, batched=True)

# from transformers import AutoModelForSequenceClassification

# num_labels = 6  # number of topics to classify in
# model = AutoModelForSequenceClassification.from_pretrained(model_checkpoint, num_labels=num_labels)

# %%
# from transformers import BertTokenizer, BertForSequenceClassification
# import torch
# import requests
# from datasets import load_dataset

# # Load pre-trained BERT model and tokenizer
# model_name = 'bert-base-uncased'
# tokenizer = BertTokenizer.from_pretrained(model_name)
# model = BertForSequenceClassification.from_pretrained(model_name)

# # Function to tokenize and process chunks of text
# def process_chunks(text_chunks):
#     tokenized_chunks = [tokenizer.encode(chunk, add_special_tokens=True, max_length=512, truncation=True) for chunk in text_chunks]
#     return tokenized_chunks

# # Function to process articles from URLs
# def process_articles_from_urls(urls):
#     for url in urls:
#         response = requests.get(url)
#         article_text = response.text

#         # Split article into chunks of 512 tokens
#         text_chunks = [article_text[i:i+512] for i in range(0, len(article_text), 512)]

#         # Process chunks
#         tokenized_chunks = process_chunks(text_chunks)

#         # Perform inference for each chunk
#         for tokens in tokenized_chunks:
#             tokens_tensor = torch.tensor(tokens).unsqueeze(0)  # Add batch dimension
#             with torch.no_grad():
#                 outputs = model(tokens_tensor)
#                 logits = outputs.logits
#                 probabilities = torch.softmax(logits, dim=-1)
#                 predicted_class = torch.argmax(probabilities).item()
#                 print("Predicted class:", predicted_class)
#                 # You can handle the results as needed

# # Process articles in train and validation sets
# train_urls = tokenized_datasets['train']['url']

# # Process articles from train set
# process_articles_from_urls(train_urls)
